# %%
import sys
import os
import datetime
import scriptCreator

def submut(parameterlist, Ncore, partition, tSDRG_path):

    p = parameterlist

    L=scriptCreator.paraList("L",parameterlist["L"])
    L_num = L.num_list
    L_p_num = L.p_num_list
    L_str = L.str_list
    L_p_str = L.p_str_list
    L_s100 = L.s100_list
    L_p_s100 = L.p_s100_list
    print("L_num:",L_num)
    print("L_p_num:",L_p_num)
    print("L_str:",L_str)
    print("L_p_str:",L_p_str)
    print("L_s100:",L_s100)
    print("L_p_s100:",L_p_s100)


    S=scriptCreator.Spara("Seed",parameterlist["seed"])
    S_num = S.toS()
    S_str = S.toStr()
    s1 = parameterlist["seed"]["s1"]
    s2 = parameterlist["seed"]["s2"]

    J=scriptCreator.paraList("Jdis",parameterlist["J"])
    J_num = J.num_list
    J_p_num = J.p_num_list
    J_str = J.str_list
    J_p_str = J.p_str_list
    J_s100 = J.s100_list
    J_p_s100 = J.p_s100_list
    
    print("J_num",J_num)
    print("J_p_num",J_p_num)
    print("J_str:",J_str)
    print("J_p_str:",J_p_str)
    print("J_s100:",J_s100)
    print("J_p_s100:",J_p_s100)
    
    D=scriptCreator.paraList("Dim",parameterlist["D"])
    D_num = D.num_list
    D_p_num = D.p_num_list
    D_str = D.str_list
    D_p_str = D.p_str_list
    D_s100 = D.s100_list
    D_p_s100 = D.p_s100_list
    
    print("D_num:",D_num)
    print("D_p_num:",D_p_num)
    print("D_str:",D_str)
    print("D_p_str:",D_p_str)
    print("D_s100:",D_s100)
    print("D_p_s100:",D_p_s100)

    Spin=parameterlist["Spin"]
    Pdis=parameterlist["Pdis"]
    dx=parameterlist["dx"]
    bondDim=parameterlist["bondDim"]
    BC=parameterlist["BC"]
    check_Or_Not=parameterlist["check_Or_Not"]

    tSDRG_record = tSDRG_path + "/tSDRG" + "/Main_" + str(Spin) + "/submit_record"
    record_dir = tSDRG_path + "/tSDRG" + "/Main_" + str(Spin) + "/jobRecord" 
    script_dir = record_dir + "/script" + "/" + str(BC) + "/B" + str(bondDim)
    output_dir = record_dir + "/slurmOutput" + "/" + str(BC) + "/B" + str(bondDim)

    tSDRG_fileName="/tSDRG_Spin=" + str(Spin) + ";BC=" + str(BC) + ";P="+ str(Pdis) + ";B=" + str(bondDim) \
        + ";L=" + str(L_p_num[0]) + "_" + str(L_p_num[1]) + "(" + str(L_p_num[2])\
        + ");J=" + str(J_num[0]) + "_" + str(J_p_num[1]) +"(" + str(round(J_p_num[2],2)) \
        + ");D=" + str(D_num[0]) + "_" + str(D_p_num[1]) + "(" + str(round(D_p_num[2],2)) +");"\
        + "seed1=" + str(s1) + "_seed2=" + str(s2) + ";Partition=" + str(partition) + ";Number_of_core=" + str(Ncore)

    nt=datetime.datetime.now()
    now_year = str(nt.year)
    now_date = str(nt.year) + "_" + str(nt.month) + "_" + str(nt.day)
    now_time = "H" + str(nt.hour) + "_M" + str(nt.minute) + "_S" + str(nt.second)
    
    tSDRG_fileDir = tSDRG_record + "/" + now_year + "/" + now_date

    if os.path.exists(tSDRG_fileDir):
        print(tSDRG_fileDir)
    else:
        os.makedirs(tSDRG_fileDir)

    tSDRG_filePath = tSDRG_fileDir + tSDRG_fileName + "_" + now_time

    with open(tSDRG_filePath, "wt") as file:
        file.write(tSDRG_fileName)

    with open("run.sh", "r") as file:
        template = file.readlines()

    print("tSDRG_filePath : ",tSDRG_filePath)
    
    os.system( "cd " + tSDRG_path + "/tSDRG/Main_" + Spin)
    
    for l_i,l in enumerate(L_str):
        for j_i,j in enumerate(J_str):
            for d_i,d in enumerate(D_str):
                for s_i in range(len(S_num)):
                    s = S_num[s_i]
                    script_path = script_dir + "/" + l + "/" + j + "/" + d  
                    output_path = output_dir + "/" + l + "/" + j + "/" + d
                    if os.path.exists(script_path):
                        pass
                        # print("exist : ", script_path)
                    else:
                        # print("not exist : ", script_path)
                        os.makedirs(script_path)
                        
                    if os.path.exists(output_path):
                        pass
                        # print("exist : ", output_path)
                    else:
                        # print("not exist : ", output_path)
                        os.makedirs(output_path)
                        
                    jobName = "Spin" + str(Spin) + "_" + l + "_" + j + "_" + d + "_" + "P" + str(Pdis) \
                                + "_" + "BC=" + str(BC) + "_B" + str(bondDim) + "_Ncore=" + Ncore + "_seed1=" \
                                    + str(s[0]) + "_seed2=" + str(s[-1]) + ""
                    script_name = jobName + "_" + now_date + "_" + now_time
                    script_path = script_path + "/" + script_name + "_random.sh"
                    output_path = output_path + "/" + script_name + "_random.out"
                    
                    # print("jobName:",jobName)
                    # print("script_name:",script_name)
                    # print("script_path:",script_path)
                    # print("output_path:",output_path)
                    
                    context = template.copy()
                    with open(script_path, "w") as file:
                        context[1] = context[1].replace("replace1", "scopion" + str(partition))
                        context[3] = context[3].replace("replace2", jobName)
                        context[4] = context[4].replace("replace3", Ncore)
                        context[5] = context[5].replace("replace4", output_path)
                        file.writelines(context)
                    
                    submit_cmd_list = ["nohup sbatch ",script_path, str(Spin),str(L_num[l_i]),str(J_num[j_i]),str(D_num[d_i])\
                    ,str(BC),str(bondDim),str(Pdis),str(s[0]),str(s[-1]),check_Or_Not,str(Ncore),tSDRG_path,output_path, ">/dev/null 2>& 1&"]

                    submit_cmd = " ".join(submit_cmd_list)
                    os.system(submit_cmd)

def find(parameterlist, Ncore, partition):
    print("find")
    p = parameterlist
    # flag = input("Job_state R/P")
    if p["status"] == "R":
        Job_state = "RUNNING"
    elif p["status"] == "P":
        Job_state = "PENDING"
    elif p["status"] == "" :
        Job_state = ""
        
    
    job_list = os.popen("squeue -u aronton " + "-p scopion" + str(partition) + " -o \"%%.12i %%.12P %%.90j %%.8T\"")

    job_list = list(job_list)

    del job_list[0]
    # print(a)
    for i in range(len(job_list)):
        job_list[i] = job_list[i].split()    


    if (p["L"]["L1"] != "") and (p["L"]["L2"] != "") and (p["L"]["dL"] != ""): 
        L=scriptCreator.paraList("L",p["L"])
        L_num = L.num_list
        L_p_num = L.p_num_list
        L_str = L.str_list
        L_p_str = L.p_str_list
        L_s100 = L.s100_list
        L_p_s100 = L.p_s100_list
        
        temp = []
        for l in L_str:
            for e in job_list:
                if l in e[2]:
                    print(l)
                    print(e[2])
                    temp.append(e)
            # if i in job_list
        job_list = temp
            # job_list = job_list + list(filter(lambda n: i in n[2],job_list))
    # else:
    #     b = a
            
    if (p["J"]["J1"] != "") and (p["J"]["J2"] != "") and (p["J"]["dJ"] != ""): 
        J=scriptCreator.paraList("Jdis",p["J"])
        J_num = J.num_list
        J_p_num = J.p_num_list
        J_str = J.str_list
        J_p_str = J.p_str_list
        J_s100 = J.s100_list
        J_p_s100 = J.p_s100_list

        temp = []
        for j in J_str:
            for e in job_list:
                if j in e[2]:
                    temp.append(e)
            # if i in job_list
        job_list = temp

        # print(J_str)
        # # c = []
        # for i in J_str:
        #     job_list = job_list + list(filter(lambda n: i in n[2],job_list))
    # else:
    #     c = b


    if (p["D"]["D1"] != "") and (p["D"]["D2"] != "") and (p["D"]["dD"] != ""): 
        D=scriptCreator.paraList("Dim",p["D"])
        D_num = D.num_list
        D_p_num = D.p_num_list
        D_str = D.str_list
        D_p_str = D.p_str_list
        D_s100 = D.s100_list
        D_p_s100 = D.p_s100_list

        temp = []
        for d in D_str:
            for e in job_list:
                if d in e[2]:
                    temp.append(e)
            # if i in job_list
        job_list = temp
        
        # print(D_str)
        # # d = []
        # for i in D_str:
        #     job_list = job_list + list(filter(lambda n: i in n[2],job_list))
    # else:
    #     d = c
            
    s1 = p["seed"]["s1"]
    s2 = p["seed"]["s2"]
    Pdis=p["Pdis"]
    dx=p["dx"]
    bondDim=p["bondDim"]
    BC=p["BC"]
    check_Or_Not=p["check_Or_Not"]
    
        
    if (p["Spin"] != ""): 
        Spin=p["Spin"]
        job_list = list(filter(lambda n: Spin in n[2],job_list))
    if (p["Pdis"] != ""): 
        Pdis=p["Pdis"]
        job_list = list(filter(lambda n: Pdis in n[2],job_list))        
    if (p["bondDim"] != ""): 
        bondDim=p["bondDim"]
        job_list = list(filter(lambda n: bondDim in n[2],job_list))   
    if (p["BC"] != ""): 
        BC=p["BC"]
        job_list = list(filter(lambda n: BC in n[2],job_list))    
    if (Job_state != ""): 
        job_list = list(filter(lambda n: Job_state in n[3],job_list))     
     
    return job_list

def cancel(parameterlist, Ncore, partition):

    job_list = find(parameterlist, Ncore, partition)

    print("Cancel : \n\n")
    print("------------------------------------------------- \n\n")

    for i in range(len(job_list)):
        cmd = "scancel " + job_list[i][0]
        print(cmd + " : " + job_list[i][2])    
        os.system(cmd)
    
def show(parameterlist, Ncore, partition):
    
    
    job_list = find(parameterlist, Ncore, partition)

    print("show\n\n")
    print("------------------------------------------------------\n\n")

    for i in range(len(job_list)):
        print(job_list[i])

# %%
task = input("What is the task? (a)submit, (b)resubmit, (c)cancel Jobs: : \n")
print(task)

parameterlist = {"Spin":None,"L":{"L1":None,"L2":None,"dL":None},"J":{"J1":None,"J2":None,"dJ":None},\
                 "D":{"D1":None,"D2":None,"dD":None},"seed":{"s1":None,"s2":None,"ds":None},\
                 "BC":None,"Pdis":None,"bondDim":None,"dx":None,"check_Or_Not":None,"status":None}
Ncore = input("Ncore : \n")
partition = input("partition : \n")
print("key in parameter in the following format : \n\
ex : Spin, L1, L2, delta_L, J1, J2, delta_J, D1, D2, delta_D, Pdis, bondDim, initialSampleNumber, finalSampleNumber, sampleDelta, check_Or_Not\n\
ex : 15(Spin) 64(L) 1.1(J) 0.1(D) 10(Pdis) 40(bondDim) 1(initialSampleNumber) 20(finalSampleNumber) 5(sampleDelta), Y(check_Or_Not)\n")

try:
    parameterlist["Spin"]=input("Spin : ")

    parameterlist["L"]["L1"]=input("L1 : ")
    parameterlist["L"]["L2"]=input("L2 : ")
    parameterlist["L"]["dL"]=input("dL : ")    

    parameterlist["J"]["J1"]=input("J1 : ")
    parameterlist["J"]["J2"]=input("J2 : ")
    parameterlist["J"]["dJ"]=input("dJ : ")

    parameterlist["D"]["D1"]=input("D1 : ")
    parameterlist["D"]["D2"]=input("D2 : ")
    parameterlist["D"]["dD"]=input("dD : ")

    parameterlist["seed"]["s1"]=input("initialSampleNumber : ")
    parameterlist["seed"]["s2"]=input("finalSampleNumber : ")
    parameterlist["seed"]["ds"]=input("sampleDelta : ")
    parameterlist["BC"] = input("BC : ")
    parameterlist["Pdis"] = input("Pdis : ")
    parameterlist["bondDim"] = input("bondDim : ")
    parameterlist["dx"] = input("dx : ")
    parameterlist["check_Or_Not"]=input("check_Or_Not(Y/N) : ")
    parameterlist["status"]=input("R/P) : ")

except KeyboardInterrupt:
    print("shut down")
    exit()



# parameterlist["Spin"]=sys.argv[0]

# parameterlist["L"]["L1"]=sys.argv[1]
# parameterlist["L"]["L2"]=sys.argv[2]
# parameterlist["L"]["dL"]=sys.argv[3]

# parameterlist["J"]["J1"]=sys.argv[4]
# parameterlist["J"]["J2"]=sys.argv[5]
# parameterlist["J"]["dJ"]=sys.argv[6]

# parameterlist["D"]["D1"]=sys.argv[7]
# parameterlist["D"]["D2"]=sys.argv[8]
# parameterlist["D"]["dD"]=sys.argv[9]

# parameterlist["seed"]["s1"]=int(sys.argv[10])
# parameterlist["seed"]["s2"]=int(sys.argv[11])
# parameterlist["seed"]["ds"]=int(sys.argv[12])
# parameterlist["BC"] = sys.argv[13]
# parameterlist["Pdis"] = int(sys.argv[14])
# parameterlist["bondDim"] = int(sys.argv[15])
# parameterlist["dx"] = int(sys.argv[16])
# parameterlist["check_Or_Not"]=sys.argv[17]



print(parameterlist,"\n")
for s in parameterlist:
    print(s," : ",parameterlist[s])

tSDRG_path="/home/aronton/tSDRG_random"

    # print("hhh")
    # for i in range(len(h)):
    #     print(h[i])
        

# def cancel(parameterlist, Ncore, partition):
    
#     p = parameterlist

#     L=scriptCreator.paraList("L",parameterlist["L"])
#     L_num = L.num_list
#     L_s100 = L.s100_list
#     L_str = L.str_list
#     L_p_num = L.p_num_list

#     print("L_num:",L_num)
#     print("L_p_num:",L_p_num)
#     print("L_str:",L_str)
#     print("L_p_str:",L_p_str)
#     print("L_s100:",L_s100)
#     print("L_p_s100:",L_p_s100)

#     S=scriptCreator.Spara("Seed",parameterlist["seed"])
#     S_num = S.toS()
#     S_str = S.toStr()
#     s1 = parameterlist["seed"]["s1"]
#     s2 = parameterlist["seed"]["s2"]

#     J=scriptCreator.paraList("Jdis",parameterlist["J"])
#     J_num = J.num_list
#     J_p_num = J.p_num_list
#     J_str = J.str_list
#     J_p_str = J.p_str_list
#     J_s100 = J.s100_list
#     J_p_s100 = J.p_s100_list

#     D=scriptCreator.paraList("Dim",parameterlist["D"])
#     D_num = D.num_list
#     D_p_num = D.p_num_list
#     D_str = D.str_list
#     D_p_str = D.p_str_list
#     D_s100 = D.s100_list
#     D_p_s100 = D.p_s100_list

#     Spin=parameterlist["Spin"]
#     Pdis=parameterlist["Pdis"]
#     dx=parameterlist["dx"]
#     bondDim=parameterlist["bondDim"]
#     BC=parameterlist["BC"]
    
#     job_list = os.popen("squeue -u aronton " + "-p scopion" + str(partition) + " -o \"%%.12i %%.12P %%.90j %%.8T\"")
#     a = list(job_list)
#     del a[0]
#     for i in range(len(a)):
#         a[i] = a[i].split()
#     print(a)
#     print(J_str)
#     b = []
#     for i in J_str:
#         b = b + list(filter(lambda n: i in n[2],a))
#     # print(list(b))
#     print(D_str)
#     c = []
#     for i in D_str:
#         c = c + list(filter(lambda n: i in n[2],b))
#     # print(list(c))
#     print(Pdis)
#     d = []
#     d = d + list(filter(lambda n: str(Pdis) in n[2],c))
#     # print(list(d))

#     e = []
#     for i in L_str:
#         e = e + list(filter(lambda n: i in n[2],d))    
#     e=list(e)
       
#     return 0

# def p_del(b, title, L_s100):
#     for l_i,l in enumerate(L_s100):
#         b=filter(lambda s : title + str(l) in s[2],b)
#     return b
# def s_del(b, S_num):
#     for s_i in range(len(S_num)):
#         seed = S_num[s_i]
#         b=filter(lambda s : "seed1=" + str(seed[0]) in s[2],b)
#         b=filter(lambda s : "seed2=" + str(seed[-1]) in s[2],b)
#     return b
if task == "a":
    print(task)
    submut(parameterlist, Ncore, partition, tSDRG_path)
elif task == "b":
    print(task)
    show(parameterlist, Ncore, partition)
elif task == "c":
    print(task)
    cancel(parameterlist, Ncore, partition)
# Out:
# b
# key in parameter in the following format :
# ex : Spin, L1, L2, delta_L, J1, J2, delta_J, D1, D2, delta_D, Pdis, bondDim, initialSampleNumber, finalSampleNumber, sampleDelta, check_Or_Not
# ex : 15(Spin) 64(L) 1.1(J) 0.1(D) 10(Pdis) 40(bondDim) 1(initialSampleNumber) 20(finalSampleNumber) 5(sampleDelta), Y(check_Or_Not)
#
# {'Spin': '15', 'L': {'L1': '512', 'L2': '512', 'dL': '0'}, 'J': {'J1': '', 'J2': '', 'dJ': ''}, 'D': {'D1': '', 'D2': '', 'dD': ''}, 'seed': {'s1': '', 's2': '', 'ds': ''}, 'BC': '', 'Pdis': '', 'bondDim': '', 'dx': '', 'check_Or_Not': '', 'status': ''}
#
# Spin  :  15
# L  :  {'L1': '512', 'L2': '512', 'dL': '0'}
# J  :  {'J1': '', 'J2': '', 'dJ': ''}
# D  :  {'D1': '', 'D2': '', 'dD': ''}
# seed  :  {'s1': '', 's2': '', 'ds': ''}
# BC  :
# Pdis  :
# bondDim  :
# dx  :
# check_Or_Not  :
# status  :
# b
# find
# ['507070', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507071', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507072', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507073', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507074', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507075', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507076', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507077', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507078', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507079', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507080', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507081', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507082', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507083', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507084', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507085', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507086', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507087', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507088', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507089', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507090', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507091', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507092', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507093', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507094', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507095', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507096', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507097', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507098', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507099', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507100', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507101', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507102', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507103', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507104', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507105', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507106', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507107', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507108', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507109', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507110', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507111', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507112', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507113', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507114', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507115', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507116', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507117', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507118', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507119', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507120', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507121', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507122', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507123', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507124', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507125', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507126', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507127', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507128', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507129', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
# ['507130', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507131', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507132', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507133', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507134', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507135', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507136', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507137', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507138', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507139', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507140', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507141', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507142', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507143', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507144', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507145', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507146', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507147', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507148', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507149', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507150', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507151', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507152', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507153', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507154', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507155', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507156', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507157', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507158', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507159', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507160', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507161', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507162', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507163', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507164', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507165', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507166', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507167', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507168', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507169', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507170', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507171', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507172', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507173', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507174', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507175', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507176', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507177', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507178', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507179', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507180', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507181', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507182', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507183', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507184', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507185', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507186', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507187', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507188', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507189', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950
# L512
# Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950
# L512
# Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000
# ddd
# ['507070', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507071', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507072', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507073', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507074', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507075', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507076', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507077', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507078', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507079', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507080', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507081', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507082', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507083', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507084', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507085', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507086', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507087', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507088', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507089', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507090', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507091', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507092', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507093', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507094', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507095', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507096', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507097', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507098', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507099', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507100', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507101', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507102', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507103', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507104', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507105', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507106', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507107', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507108', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507109', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507110', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507111', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507112', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507113', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507114', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507115', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507116', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507117', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507118', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507119', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507120', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507121', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507122', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507123', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507124', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507125', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507126', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507127', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507128', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507129', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
# ['507130', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507131', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507132', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507133', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507134', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507135', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507136', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507137', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507138', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507139', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507140', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507141', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507142', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507143', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507144', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507145', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507146', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507147', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507148', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507149', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507150', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507151', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507152', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507153', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507154', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507155', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507156', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507157', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507158', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507159', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507160', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507161', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507162', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507163', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507164', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507165', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507166', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507167', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507168', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507169', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507170', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507171', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507172', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507173', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507174', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507175', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507176', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507177', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507178', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507179', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507180', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507181', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507182', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507183', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507184', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507185', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507186', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507187', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507188', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507189', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
# show
#
#
# ------------------------------------------------------
#
#
# ['507070', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507071', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507072', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507073', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507074', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507075', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507076', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507077', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507078', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507079', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507080', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507081', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507082', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507083', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507084', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507085', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507086', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507087', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507088', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507089', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507090', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507091', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507092', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507093', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507094', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507095', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507096', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507097', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507098', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507099', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507100', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507101', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507102', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507103', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507104', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507105', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507106', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507107', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507108', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507109', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507110', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507111', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507112', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507113', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507114', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507115', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507116', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507117', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507118', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507119', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507120', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507121', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507122', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507123', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507124', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507125', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507126', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507127', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507128', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507129', 'scopion1', 'Spin15_L512_Jdis119_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
# ['507130', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1_seed2=50', 'RUNNING']
# ['507131', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=51_seed2=100', 'RUNNING']
# ['507132', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=101_seed2=150', 'RUNNING']
# ['507133', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=151_seed2=200', 'RUNNING']
# ['507134', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=201_seed2=250', 'RUNNING']
# ['507135', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=251_seed2=300', 'RUNNING']
# ['507136', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=301_seed2=350', 'RUNNING']
# ['507137', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=351_seed2=400', 'RUNNING']
# ['507138', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=401_seed2=450', 'RUNNING']
# ['507139', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=451_seed2=500', 'RUNNING']
# ['507140', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=501_seed2=550', 'RUNNING']
# ['507141', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=551_seed2=600', 'RUNNING']
# ['507142', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=601_seed2=650', 'RUNNING']
# ['507143', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=651_seed2=700', 'RUNNING']
# ['507144', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=701_seed2=750', 'RUNNING']
# ['507145', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=751_seed2=800', 'RUNNING']
# ['507146', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=801_seed2=850', 'RUNNING']
# ['507147', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=851_seed2=900', 'RUNNING']
# ['507148', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=901_seed2=950', 'RUNNING']
# ['507149', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=951_seed2=1000', 'RUNNING']
# ['507150', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1001_seed2=1050', 'RUNNING']
# ['507151', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1051_seed2=1100', 'RUNNING']
# ['507152', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1101_seed2=1150', 'RUNNING']
# ['507153', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1151_seed2=1200', 'RUNNING']
# ['507154', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1201_seed2=1250', 'RUNNING']
# ['507155', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1251_seed2=1300', 'RUNNING']
# ['507156', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1301_seed2=1350', 'RUNNING']
# ['507157', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1351_seed2=1400', 'RUNNING']
# ['507158', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1401_seed2=1450', 'RUNNING']
# ['507159', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1451_seed2=1500', 'RUNNING']
# ['507160', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1501_seed2=1550', 'RUNNING']
# ['507161', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1551_seed2=1600', 'RUNNING']
# ['507162', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1601_seed2=1650', 'RUNNING']
# ['507163', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1651_seed2=1700', 'RUNNING']
# ['507164', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1701_seed2=1750', 'RUNNING']
# ['507165', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1751_seed2=1800', 'RUNNING']
# ['507166', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1801_seed2=1850', 'RUNNING']
# ['507167', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1851_seed2=1900', 'RUNNING']
# ['507168', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1901_seed2=1950', 'RUNNING']
# ['507169', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=1951_seed2=2000', 'RUNNING']
# ['507170', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2001_seed2=2050', 'RUNNING']
# ['507171', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2051_seed2=2100', 'RUNNING']
# ['507172', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2101_seed2=2150', 'RUNNING']
# ['507173', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2151_seed2=2200', 'RUNNING']
# ['507174', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2201_seed2=2250', 'RUNNING']
# ['507175', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2251_seed2=2300', 'RUNNING']
# ['507176', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2301_seed2=2350', 'RUNNING']
# ['507177', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2351_seed2=2400', 'RUNNING']
# ['507178', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2401_seed2=2450', 'RUNNING']
# ['507179', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2451_seed2=2500', 'RUNNING']
# ['507180', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2501_seed2=2550', 'RUNNING']
# ['507181', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2551_seed2=2600', 'RUNNING']
# ['507182', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2601_seed2=2650', 'RUNNING']
# ['507183', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2651_seed2=2700', 'RUNNING']
# ['507184', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2701_seed2=2750', 'RUNNING']
# ['507185', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2751_seed2=2800', 'RUNNING']
# ['507186', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2801_seed2=2850', 'RUNNING']
# ['507187', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2851_seed2=2900', 'RUNNING']
# ['507188', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2901_seed2=2950', 'RUNNING']
# ['507189', 'scopion1', 'Spin15_L512_Jdis120_Dim000_P20_BC=PBC_B40_Ncore=1_seed1=2951_seed2=3000', 'RUNNING']
