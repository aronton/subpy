# %%
import sys
import os
import datetime
import scriptCreator

def submut(parameterlist, Ncore, partition, tSDRG_path):

    p = parameterlist

    L=scriptCreator.paraList("L",parameterlist["L"])
    L_num = L.num_list
    L_p_num = L.p_num_list
    L_str = L.str_list
    L_p_str = L.p_str_list
    L_s100 = L.s100_list
    L_p_s100 = L.p_s100_list
    print("L_num:",L_num)
    print("L_p_num:",L_p_num)
    print("L_str:",L_str)
    print("L_p_str:",L_p_str)
    print("L_s100:",L_s100)
    print("L_p_s100:",L_p_s100)


    S=scriptCreator.Spara("Seed",parameterlist["seed"])
    S_num = S.toS()
    S_str = S.toStr()
    s1 = parameterlist["seed"]["s1"]
    s2 = parameterlist["seed"]["s2"]

    J=scriptCreator.paraList("Jdis",parameterlist["J"])
    J_num = J.num_list
    J_p_num = J.p_num_list
    J_str = J.str_list
    J_p_str = J.p_str_list
    J_s100 = J.s100_list
    J_p_s100 = J.p_s100_list
    
    print("J_num",J_num)
    print("J_p_num",J_p_num)
    print("J_str:",J_str)
    print("J_p_str:",J_p_str)
    print("J_s100:",J_s100)
    print("J_p_s100:",J_p_s100)
    
    D=scriptCreator.paraList("Dim",parameterlist["D"])
    D_num = D.num_list
    D_p_num = D.p_num_list
    D_str = D.str_list
    D_p_str = D.p_str_list
    D_s100 = D.s100_list
    D_p_s100 = D.p_s100_list
    
    print("D_num:",D_num)
    print("D_p_num:",D_p_num)
    print("D_str:",D_str)
    print("D_p_str:",D_p_str)
    print("D_s100:",D_s100)
    print("D_p_s100:",D_p_s100)

    Spin=parameterlist["Spin"]
    Pdis=parameterlist["Pdis"]
    dx=parameterlist["dx"]
    bondDim=parameterlist["bondDim"]
    BC=parameterlist["BC"]
    check_Or_Not=parameterlist["check_Or_Not"]

    tSDRG_record = tSDRG_path + "/tSDRG" + "/Main_" + str(Spin) + "/submit_record"
    record_dir = tSDRG_path + "/tSDRG" + "/Main_" + str(Spin) + "/jobRecord" 
    script_dir = record_dir + "/script" + "/" + str(BC) + "/B" + str(bondDim)
    output_dir = record_dir + "/slurmOutput" + "/" + str(BC) + "/B" + str(bondDim)

    tSDRG_fileName="/tSDRG_Spin=" + str(Spin) + ";BC=" + str(BC) + ";P="+ str(Pdis) + ";B=" + str(bondDim) \
        + ";L=" + str(L_p_num[0]) + "_" + str(L_p_num[1]) + "(" + str(L_p_num[2])\
        + ");J=" + str(J_num[0]) + "_" + str(J_p_num[1]) +"(" + str(round(J_p_num[2],2)) \
        + ");D=" + str(D_num[0]) + "_" + str(D_p_num[1]) + "(" + str(round(D_p_num[2],2)) +");"\
        + "seed1=" + str(s1) + "_seed2=" + str(s2) + ";Partition=" + str(partition) + ";Number_of_core=" + str(Ncore)

    nt=datetime.datetime.now()
    now_year = str(nt.year)
    now_date = str(nt.year) + "_" + str(nt.month) + "_" + str(nt.day)
    now_time = "H" + str(nt.hour) + "_M" + str(nt.minute) + "_S" + str(nt.second)
    
    tSDRG_fileDir = tSDRG_record + "/" + now_year + "/" + now_date

    if os.path.exists(tSDRG_fileDir):
        print(tSDRG_fileDir)
    else:
        os.makedirs(tSDRG_fileDir)

    tSDRG_filePath = tSDRG_fileDir + tSDRG_fileName + "_" + now_time

    with open(tSDRG_filePath, "wt") as file:
        file.write(tSDRG_fileName)

    with open("run.sh", "r") as file:
        template = file.readlines()

    print("tSDRG_filePath : ",tSDRG_filePath)
    
    os.system( "cd " + tSDRG_path + "/tSDRG/Main_" + Spin)
    
    for l_i,l in enumerate(L_str):
        for j_i,j in enumerate(J_str):
            for d_i,d in enumerate(D_str):
                for s_i in range(len(S_num)):
                    s = S_num[s_i]
                    script_path = script_dir + "/" + l + "/" + j + "/" + d  
                    output_path = output_dir + "/" + l + "/" + j + "/" + d
                    if os.path.exists(script_path):
                        pass
                        # print("exist : ", script_path)
                    else:
                        # print("not exist : ", script_path)
                        os.makedirs(script_path)
                        
                    if os.path.exists(output_path):
                        pass
                        # print("exist : ", output_path)
                    else:
                        # print("not exist : ", output_path)
                        os.makedirs(output_path)
                        
                    jobName = "Spin" + str(Spin) + "_" + l + "_" + j + "_" + d + "_" + "P" + str(Pdis) \
                                + "_" + "BC=" + str(BC) + "_B" + str(bondDim) + "_Ncore=" + Ncore + "_seed1=" \
                                    + str(s[0]) + "_seed2=" + str(s[-1]) + ""
                    script_name = jobName + "_" + now_date + "_" + now_time
                    script_path = script_path + "/" + script_name + "_random.sh"
                    output_path = output_path + "/" + script_name + "_random.out"
                    
                    # print("jobName:",jobName)
                    # print("script_name:",script_name)
                    # print("script_path:",script_path)
                    # print("output_path:",output_path)
                    
                    context = template.copy()
                    with open(script_path, "w") as file:
                        context[1] = context[1].replace("replace1", "scopion" + str(partition))
                        context[3] = context[3].replace("replace2", jobName)
                        context[4] = context[4].replace("replace3", Ncore)
                        context[5] = context[5].replace("replace4", output_path)
                        file.writelines(context)
                    
                    submit_cmd_list = ["nohup sbatch ",script_path, str(Spin),str(L_num[l_i]),str(J_num[j_i]),str(D_num[d_i])\
                    ,str(BC),str(bondDim),str(Pdis),str(s[0]),str(s[-1]),check_Or_Not,str(Ncore),tSDRG_path,output_path, ">/dev/null 2>& 1&"]

                    submit_cmd = " ".join(submit_cmd_list)
                    os.system(submit_cmd)

def find(parameterlist, Ncore, partition):
    print("find")
    
    flag = input("Job_state R/P")
    if flag == "R":
        Job_state = "RUNNING"
    elif flag == "P":
        Job_state = "PENDING"
        
    p = parameterlist
    
    job_list = os.popen("squeue -u aronton " + "-p scopion" + str(partition) + " -o \"%%.12i %%.12P %%.90j %%.8T\"")

    a = list(job_list)

    del a[0]
    # print(a)
    for i in range(len(a)):
        a[i] = a[i].split()    
    for i in range(len(a)):
        print(a[i])
    # print(a)

    if (p["L"]["L1"] != "") and (p["L"]["L2"] != "") and (p["L"]["dL"] != ""): 
        L=scriptCreator.paraList("L",p["L"])
        L_num = L.num_list
        L_p_num = L.p_num_list
        L_str = L.str_list
        L_p_str = L.p_str_list
        L_s100 = L.s100_list
        L_p_s100 = L.p_s100_list
        print(L_str)
        b = []
        for i in L_str:
            b = b + list(filter(lambda n: i in n[2],a))
            
    if (p["J"]["J1"] != "") and (p["J"]["J2"] != "") and (p["J"]["dJ"] != ""): 
        J=scriptCreator.paraList("Jdis",p["J"])
        J_num = J.num_list
        J_p_num = J.p_num_list
        J_str = J.str_list
        J_p_str = J.p_str_list
        J_s100 = J.s100_list
        J_p_s100 = J.p_s100_list

        print(J_str)
        c = []
        for i in J_str:
            c = c + list(filter(lambda n: i in n[2],b))


    if (p["D"]["D1"] != "") and (p["D"]["D2"] != "") and (p["D"]["dD"] != ""): 
        D=scriptCreator.paraList("Dim",p["D"])
        D_num = D.num_list
        D_p_num = D.p_num_list
        D_str = D.str_list
        D_p_str = D.p_str_list
        D_s100 = D.s100_list
        D_p_s100 = D.p_s100_list
        
        print(D_str)
        d = []
        for i in D_str:
            d = d + list(filter(lambda n: i in n[2],c))
            
    s1 = p["seed"]["s1"]
    s2 = p["seed"]["s2"]
    Pdis=p["Pdis"]
    dx=p["dx"]
    bondDim=p["bondDim"]
    BC=p["BC"]
    check_Or_Not=p["check_Or_Not"]
    
    print("ddd")
    for i in range(len(d)):
        print(d[i])    
        
    if (p["Spin"] != ""): 
        Spin=p["Spin"]
        e = list(filter(lambda n: Spin in n[2],d))
    if (p["Pdis"] != ""): 
        print(type(Pdis))
        Pdis=p["Pdis"]
        f = list(filter(lambda n: Pdis in n[2],e))        
    if (p["bondDim"] != ""): 
        bondDim=p["bondDim"]
        g = list(filter(lambda n: bondDim in n[2],f))   
    if (p["BC"] != ""): 
        BC=p["BC"]
        h = list(filter(lambda n: BC in n[2],g))    
    if (Job_state != ""): 
        final = list(filter(lambda n: Job_state in n[3],h))     
     
    return final

def show(parameterlist, Ncore, partition):
    
    print("show")
    job_list = find(parameterlist, Ncore, partition)
    # p = parameterlist
    
    # job_list = os.popen("squeue -u aronton " + "-p scopion" + str(partition) + " -o \"%%.12i %%.12P %%.90j %%.8T\"")

    # a = list(job_list)

    # print(a)

    for i in range(len(job_list)):
        print(job_list[i])
    # print(a)

    # if (p["L"]["L1"] != "") and (p["L"]["L2"] != "") and (p["L"]["dL"] != ""): 
    #     L=scriptCreator.paraList("L",p["L"])
    #     L_num = L.num_list
    #     L_p_num = L.p_num_list
    #     L_str = L.str_list
    #     L_p_str = L.p_str_list
    #     L_s100 = L.s100_list
    #     L_p_s100 = L.p_s100_list
    #     print(L_str)
    #     b = []
    #     for i in L_str:
    #         b = b + list(filter(lambda n: i in n[2],a))
            
    # if (p["J"]["J1"] != "") and (p["J"]["J2"] != "") and (p["J"]["dJ"] != ""): 
    #     J=scriptCreator.paraList("Jdis",p["J"])
    #     J_num = J.num_list
    #     J_p_num = J.p_num_list
    #     J_str = J.str_list
    #     J_p_str = J.p_str_list
    #     J_s100 = J.s100_list
    #     J_p_s100 = J.p_s100_list

    #     print(J_str)
    #     c = []
    #     for i in J_str:
    #         c = c + list(filter(lambda n: i in n[2],b))


    # if (p["D"]["D1"] != "") and (p["D"]["D2"] != "") and (p["D"]["dD"] != ""): 
    #     D=scriptCreator.paraList("Dim",p["D"])
    #     D_num = D.num_list
    #     D_p_num = D.p_num_list
    #     D_str = D.str_list
    #     D_p_str = D.p_str_list
    #     D_s100 = D.s100_list
    #     D_p_s100 = D.p_s100_list
        
    #     print(D_str)
    #     d = []
    #     for i in D_str:
    #         d = d + list(filter(lambda n: i in n[2],c))
            
    # s1 = p["seed"]["s1"]
    # s2 = p["seed"]["s2"]
    # Pdis=p["Pdis"]
    # dx=p["dx"]
    # bondDim=p["bondDim"]
    # BC=p["BC"]
    # check_Or_Not=p["check_Or_Not"]
    
    # print("ddd")
    # for i in range(len(d)):
    #     print(d[i])    
        
    # if (p["Spin"] != ""): 
    #     Spin=p["Spin"]
    #     e = list(filter(lambda n: Spin in n[2],d))
    # if (p["Pdis"] != ""): 
    #     print(type(Pdis))
    #     Pdis=p["Pdis"]
    #     f = list(filter(lambda n: Pdis in n[2],e))        
    # if (p["bondDim"] != ""): 
    #     bondDim=p["bondDim"]
    #     g = list(filter(lambda n: bondDim in n[2],f))   
    # if (p["BC"] != ""): 
    #     BC=p["BC"]
    #     h = list(filter(lambda n: BC in n[2],g))     
        
    # print("hhh")
    # for i in range(len(h)):
    #     print(h[i])

# %%
task = input("What is the task? (a)submit, (b)resubmit, (c)cancel Jobs: : \n")
print(task)

parameterlist = {"Spin":None,"L":{"L1":None,"L2":None,"dL":None},"J":{"J1":None,"J2":None,"dJ":None},\
                 "D":{"D1":None,"D2":None,"dD":None},"seed":{"s1":None,"s2":None,"ds":None},\
                 "BC":None,"Pdis":None,"bondDim":None,"dx":None,"check_Or_Not":None}
Ncore = input("Ncore : \n")
partition = input("partition : \n")
print("key in parameter in the following format : \n\
ex : Spin, L1, L2, delta_L, J1, J2, delta_J, D1, D2, delta_D, Pdis, bondDim, initialSampleNumber, finalSampleNumber, sampleDelta, check_Or_Not\n\
ex : 15(Spin) 64(L) 1.1(J) 0.1(D) 10(Pdis) 40(bondDim) 1(initialSampleNumber) 20(finalSampleNumber) 5(sampleDelta), Y(check_Or_Not)\n")

try:
    parameterlist["Spin"]=input("Spin : ")

    parameterlist["L"]["L1"]=input("L1 : ")
    parameterlist["L"]["L2"]=input("L2 : ")
    parameterlist["L"]["dL"]=input("dL : ")    

    parameterlist["J"]["J1"]=input("J1 : ")
    parameterlist["J"]["J2"]=input("J2 : ")
    parameterlist["J"]["dJ"]=input("dJ : ")

    parameterlist["D"]["D1"]=input("D1 : ")
    parameterlist["D"]["D2"]=input("D2 : ")
    parameterlist["D"]["dD"]=input("dD : ")

    parameterlist["seed"]["s1"]=input("initialSampleNumber : ")
    parameterlist["seed"]["s2"]=input("finalSampleNumber : ")
    parameterlist["seed"]["ds"]=input("sampleDelta : ")
    parameterlist["BC"] = input("BC : ")
    parameterlist["Pdis"] = input("Pdis : ")
    parameterlist["bondDim"] = input("bondDim : ")
    parameterlist["dx"] = input("dx : ")
    parameterlist["check_Or_Not"]=input("check_Or_Not(Y/N) : ")
except KeyboardInterrupt:
    print("shut down")
    exit()



# parameterlist["Spin"]=sys.argv[0]

# parameterlist["L"]["L1"]=sys.argv[1]
# parameterlist["L"]["L2"]=sys.argv[2]
# parameterlist["L"]["dL"]=sys.argv[3]

# parameterlist["J"]["J1"]=sys.argv[4]
# parameterlist["J"]["J2"]=sys.argv[5]
# parameterlist["J"]["dJ"]=sys.argv[6]

# parameterlist["D"]["D1"]=sys.argv[7]
# parameterlist["D"]["D2"]=sys.argv[8]
# parameterlist["D"]["dD"]=sys.argv[9]

# parameterlist["seed"]["s1"]=int(sys.argv[10])
# parameterlist["seed"]["s2"]=int(sys.argv[11])
# parameterlist["seed"]["ds"]=int(sys.argv[12])
# parameterlist["BC"] = sys.argv[13]
# parameterlist["Pdis"] = int(sys.argv[14])
# parameterlist["bondDim"] = int(sys.argv[15])
# parameterlist["dx"] = int(sys.argv[16])
# parameterlist["check_Or_Not"]=sys.argv[17]



print(parameterlist,"\n")
for s in parameterlist:
    print(s," : ",parameterlist[s])

tSDRG_path="/home/aronton/tSDRG_random"

    # print("hhh")
    # for i in range(len(h)):
    #     print(h[i])
        

# def cancel(parameterlist, Ncore, partition):
    
#     p = parameterlist

#     L=scriptCreator.paraList("L",parameterlist["L"])
#     L_num = L.num_list
#     L_s100 = L.s100_list
#     L_str = L.str_list
#     L_p_num = L.p_num_list

#     print("L_num:",L_num)
#     print("L_p_num:",L_p_num)
#     print("L_str:",L_str)
#     print("L_p_str:",L_p_str)
#     print("L_s100:",L_s100)
#     print("L_p_s100:",L_p_s100)

#     S=scriptCreator.Spara("Seed",parameterlist["seed"])
#     S_num = S.toS()
#     S_str = S.toStr()
#     s1 = parameterlist["seed"]["s1"]
#     s2 = parameterlist["seed"]["s2"]

#     J=scriptCreator.paraList("Jdis",parameterlist["J"])
#     J_num = J.num_list
#     J_p_num = J.p_num_list
#     J_str = J.str_list
#     J_p_str = J.p_str_list
#     J_s100 = J.s100_list
#     J_p_s100 = J.p_s100_list

#     D=scriptCreator.paraList("Dim",parameterlist["D"])
#     D_num = D.num_list
#     D_p_num = D.p_num_list
#     D_str = D.str_list
#     D_p_str = D.p_str_list
#     D_s100 = D.s100_list
#     D_p_s100 = D.p_s100_list

#     Spin=parameterlist["Spin"]
#     Pdis=parameterlist["Pdis"]
#     dx=parameterlist["dx"]
#     bondDim=parameterlist["bondDim"]
#     BC=parameterlist["BC"]
    
#     job_list = os.popen("squeue -u aronton " + "-p scopion" + str(partition) + " -o \"%%.12i %%.12P %%.90j %%.8T\"")
#     a = list(job_list)
#     del a[0]
#     for i in range(len(a)):
#         a[i] = a[i].split()
#     print(a)
#     print(J_str)
#     b = []
#     for i in J_str:
#         b = b + list(filter(lambda n: i in n[2],a))
#     # print(list(b))
#     print(D_str)
#     c = []
#     for i in D_str:
#         c = c + list(filter(lambda n: i in n[2],b))
#     # print(list(c))
#     print(Pdis)
#     d = []
#     d = d + list(filter(lambda n: str(Pdis) in n[2],c))
#     # print(list(d))

#     e = []
#     for i in L_str:
#         e = e + list(filter(lambda n: i in n[2],d))    
#     e=list(e)
       
#     return 0

# def p_del(b, title, L_s100):
#     for l_i,l in enumerate(L_s100):
#         b=filter(lambda s : title + str(l) in s[2],b)
#     return b
# def s_del(b, S_num):
#     for s_i in range(len(S_num)):
#         seed = S_num[s_i]
#         b=filter(lambda s : "seed1=" + str(seed[0]) in s[2],b)
#         b=filter(lambda s : "seed2=" + str(seed[-1]) in s[2],b)
#     return b
if task == "a":
    print(task)
    submut(parameterlist, Ncore, partition, tSDRG_path)
elif task == "b":
    print(task)
    show(parameterlist, Ncore, partition)
else:
    pass
# Out:
# b
# key in parameter in the following format :
# ex : Spin, L1, L2, delta_L, J1, J2, delta_J, D1, D2, delta_D, Pdis, bondDim, initialSampleNumber, finalSampleNumber, sampleDelta, check_Or_Not
# ex : 15(Spin) 64(L) 1.1(J) 0.1(D) 10(Pdis) 40(bondDim) 1(initialSampleNumber) 20(finalSampleNumber) 5(sampleDelta), Y(check_Or_Not)
#
# {'Spin': '15', 'L': {'L1': '128', 'L2': '512', 'dL': '128'}, 'J': {'J1': '1', 'J2': '1.2', 'dJ': '0.01'}, 'D': {'D1': '0', 'D2': '0', 'dD': '0'}, 'seed': {'s1': '1', 's2': '3000', 'ds': '50'}, 'BC': 'PBC', 'Pdis': '20', 'bondDim': '40', 'dx': '0', 'check_Or_Not': 'Y'}
#
# Spin  :  15
# L  :  {'L1': '128', 'L2': '512', 'dL': '128'}
# J  :  {'J1': '1', 'J2': '1.2', 'dJ': '0.01'}
# D  :  {'D1': '0', 'D2': '0', 'dD': '0'}
# seed  :  {'s1': '1', 's2': '3000', 'ds': '50'}
# BC  :  PBC
# Pdis  :  20
# bondDim  :  40
# dx  :  0
# check_Or_Not  :  Y
# b
# show
# find
# ['502139', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502140', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502141', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502142', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502143', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502144', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502145', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502146', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502147', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502148', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502149', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502150', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502151', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502152', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502153', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502154', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502155', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502156', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502157', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502158', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502159', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502160', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502161', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502162', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502163', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502164', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502165', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502166', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502167', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502168', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502169', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502170', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502171', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502172', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502173', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502174', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502175', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502176', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502177', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502178', 'scopion2', 'spin15_L512_Jdis111_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502359', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502360', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502361', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502362', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502363', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502364', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502365', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502366', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502367', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502368', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502369', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502370', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502371', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502372', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502373', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502374', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502375', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502376', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502377', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502378', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502379', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502380', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502381', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502382', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502383', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502384', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502385', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502386', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502387', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502388', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502389', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502390', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502391', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502392', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502393', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502394', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502395', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502396', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502397', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502398', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502399', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502400', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502401', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502402', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502403', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502404', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502405', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502406', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502407', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502408', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502409', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502410', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502411', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502412', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502413', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502414', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502415', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502416', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502417', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502418', 'scopion2', 'spin15_L512_Jdis115_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502419', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502420', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502421', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502422', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502423', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502424', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502425', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502426', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502427', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502428', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502429', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502430', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502431', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502432', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502433', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502434', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502435', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502436', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502437', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502438', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502439', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502440', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502441', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502442', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502443', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502444', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502445', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502446', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502447', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502448', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502449', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502450', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502451', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502452', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502453', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502454', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502455', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502456', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502457', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502458', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502459', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502460', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502461', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502462', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502463', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502464', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502465', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502466', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502467', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502468', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502469', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502470', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502471', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502472', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502473', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502474', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502475', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502476', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502477', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502478', 'scopion2', 'spin15_L512_Jdis116_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502479', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502480', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502481', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502482', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502483', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502484', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502485', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502486', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502487', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502488', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502489', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502490', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502491', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502492', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502493', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502494', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502495', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502496', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502497', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502498', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502499', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502500', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502501', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502502', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502503', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502504', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502505', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502506', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502507', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502508', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502509', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502510', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502511', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502512', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502513', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502514', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502515', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502516', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502517', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502518', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502519', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502520', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502521', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502522', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502523', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502524', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502525', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502526', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502527', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502528', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502529', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502530', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502531', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502532', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502533', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502534', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502535', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502536', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502537', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502538', 'scopion2', 'spin15_L512_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502539', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502540', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502541', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502542', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502543', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502544', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502545', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502546', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502547', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502548', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502549', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502550', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502551', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502552', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502553', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502554', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502555', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502556', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502557', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502558', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502559', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502560', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502561', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502562', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502563', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502564', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502565', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502566', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502567', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502568', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502569', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502570', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502571', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502572', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502573', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502574', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502575', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502576', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502577', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502578', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502579', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502580', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502581', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502582', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502583', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502584', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502585', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502586', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502587', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502588', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502589', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502590', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502591', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502592', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502593', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502594', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502595', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502596', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502597', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502598', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502599', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502600', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502601', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502602', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502603', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502604', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502605', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502606', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502607', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502608', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502609', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502610', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502611', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502612', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502613', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502614', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502615', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502616', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502617', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502618', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502619', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502620', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502621', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502622', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502623', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502624', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502625', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502626', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502627', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502628', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502629', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502630', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502631', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502632', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502633', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502634', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502635', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502636', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502637', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502638', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502639', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502640', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502641', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502642', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502643', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502644', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502645', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502646', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502647', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502648', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502649', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502650', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502651', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502652', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502653', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502654', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502655', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502656', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502657', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502658', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502659', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502660', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502661', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502662', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502663', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502664', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502665', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502666', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502667', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502668', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502669', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502670', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502671', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502672', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502673', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502674', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502675', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502676', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502677', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502678', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502679', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502680', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502681', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502682', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502683', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502684', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502685', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502686', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502687', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502688', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502689', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502690', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502691', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502692', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502693', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502694', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502695', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502696', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502697', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502698', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502699', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502700', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502701', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502702', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502703', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502704', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502705', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502706', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502707', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502708', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502709', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502710', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502711', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502712', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502713', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502714', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502715', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502716', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502717', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502718', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['501921', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'RUNNING']
# ['501924', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'RUNNING']
# ['501926', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'RUNNING']
# ['501929', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'RUNNING']
# ['501931', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'RUNNING']
# ['501933', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'RUNNING']
# ['501934', 'scopion2', 'spin15_L384_Jdis117_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'RUNNING']
# ['501971', 'scopion2', 'spin15_L384_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'RUNNING']
# ...
# ['502581', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502582', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502583', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502584', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502585', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502586', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502587', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502588', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502589', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502590', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502591', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502592', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502593', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502594', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502595', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502596', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502597', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502598', 'scopion2', 'spin15_L512_Jdis118_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502599', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502600', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502601', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502602', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502603', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502604', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502605', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502606', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502607', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502608', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502609', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502610', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502611', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502612', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502613', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502614', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502615', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502616', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502617', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502618', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502619', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502620', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502621', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502622', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502623', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502624', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502625', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502626', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502627', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502628', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502629', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502630', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502631', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502632', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502633', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502634', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502635', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502636', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502637', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502638', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502639', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502640', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502641', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502642', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502643', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502644', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502645', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502646', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502647', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502648', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502649', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502650', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502651', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502652', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502653', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502654', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502655', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502656', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502657', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502658', 'scopion2', 'spin15_L512_Jdis119_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
# ['502659', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1_seed2=50_random', 'PENDING']
# ['502660', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=51_seed2=100_random', 'PENDING']
# ['502661', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=101_seed2=150_random', 'PENDING']
# ['502662', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=151_seed2=200_random', 'PENDING']
# ['502663', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=201_seed2=250_random', 'PENDING']
# ['502664', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=251_seed2=300_random', 'PENDING']
# ['502665', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=301_seed2=350_random', 'PENDING']
# ['502666', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=351_seed2=400_random', 'PENDING']
# ['502667', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=401_seed2=450_random', 'PENDING']
# ['502668', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=451_seed2=500_random', 'PENDING']
# ['502669', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=501_seed2=550_random', 'PENDING']
# ['502670', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=551_seed2=600_random', 'PENDING']
# ['502671', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=601_seed2=650_random', 'PENDING']
# ['502672', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=651_seed2=700_random', 'PENDING']
# ['502673', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=701_seed2=750_random', 'PENDING']
# ['502674', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=751_seed2=800_random', 'PENDING']
# ['502675', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=801_seed2=850_random', 'PENDING']
# ['502676', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=851_seed2=900_random', 'PENDING']
# ['502677', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=901_seed2=950_random', 'PENDING']
# ['502678', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=951_seed2=1000_random', 'PENDING']
# ['502679', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1001_seed2=1050_random', 'PENDING']
# ['502680', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1051_seed2=1100_random', 'PENDING']
# ['502681', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1101_seed2=1150_random', 'PENDING']
# ['502682', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1151_seed2=1200_random', 'PENDING']
# ['502683', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1201_seed2=1250_random', 'PENDING']
# ['502684', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1251_seed2=1300_random', 'PENDING']
# ['502685', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1301_seed2=1350_random', 'PENDING']
# ['502686', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1351_seed2=1400_random', 'PENDING']
# ['502687', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1401_seed2=1450_random', 'PENDING']
# ['502688', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1451_seed2=1500_random', 'PENDING']
# ['502689', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1501_seed2=1550_random', 'PENDING']
# ['502690', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1551_seed2=1600_random', 'PENDING']
# ['502691', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1601_seed2=1650_random', 'PENDING']
# ['502692', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1651_seed2=1700_random', 'PENDING']
# ['502693', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1701_seed2=1750_random', 'PENDING']
# ['502694', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1751_seed2=1800_random', 'PENDING']
# ['502695', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1801_seed2=1850_random', 'PENDING']
# ['502696', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1851_seed2=1900_random', 'PENDING']
# ['502697', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1901_seed2=1950_random', 'PENDING']
# ['502698', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=1951_seed2=2000_random', 'PENDING']
# ['502699', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2001_seed2=2050_random', 'PENDING']
# ['502700', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2051_seed2=2100_random', 'PENDING']
# ['502701', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2101_seed2=2150_random', 'PENDING']
# ['502702', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2151_seed2=2200_random', 'PENDING']
# ['502703', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2201_seed2=2250_random', 'PENDING']
# ['502704', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2251_seed2=2300_random', 'PENDING']
# ['502705', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2301_seed2=2350_random', 'PENDING']
# ['502706', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2351_seed2=2400_random', 'PENDING']
# ['502707', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2401_seed2=2450_random', 'PENDING']
# ['502708', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2451_seed2=2500_random', 'PENDING']
# ['502709', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2501_seed2=2550_random', 'PENDING']
# ['502710', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2551_seed2=2600_random', 'PENDING']
# ['502711', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2601_seed2=2650_random', 'PENDING']
# ['502712', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2651_seed2=2700_random', 'PENDING']
# ['502713', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2701_seed2=2750_random', 'PENDING']
# ['502714', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2751_seed2=2800_random', 'PENDING']
# ['502715', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2801_seed2=2850_random', 'PENDING']
# ['502716', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2851_seed2=2900_random', 'PENDING']
# ['502717', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2901_seed2=2950_random', 'PENDING']
# ['502718', 'scopion2', 'spin15_L512_Jdis120_Dim000_P20_B40_BC=PBC_Ncore=1_seed1=2951_seed2=3000_random', 'PENDING']
